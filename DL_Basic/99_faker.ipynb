# %% [markdown]
# # Faker
# - 가상 데이터 생성

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-35.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\user\anaconda3\envs\pystudy_env\lib\site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\envs\pystudy_env\lib\site-packages (from faker) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\pystudy_env\lib\site-packages (from python-dateutil>=2.4->faker) (1.17.0)
# Downloading Faker-35.2.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.9 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/1.9 MB 1.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 0.8/1.9 MB 1.2 MB/s eta 0:00:01
#    --------------------- ------------------ 1.0/1.9 MB 1.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 1.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/1.9 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 1.2 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-35.2.0

# %%
from faker import Faker

fake = Faker()
print(fake.name())
print(fake.first_name() + "," + fake.last_name())
print(fake.email())
print(fake.company())
print(fake.date_of_birth(minimum_age=19, maximum_age=90))
# Out:
# Christopher Johnson
# Adam,Davenport
# tammyrowe@example.com
# Pacheco LLC
# 1979-12-25

# %%
import pandas as pd
import random

fake = Faker()

def generate_customer_data(n=1000):
    data = []

    for _ in range(n):
        age = fake.random_int(min=19, max=60)
        sub_months = fake.random_int(min=1, max=120)
        monthly_payment = round(random.uniform(10, 100), 2)
        usage_frequency = fake.random_int(min=1, max=30)
        stft_score = fake.random_int(min=1, max=5)
        churn = fake.boolean(chance_of_getting_true=30)

        data.append([
            age, sub_months, monthly_payment, usage_frequency, stft_score, churn
        ])

    columns = ["AGE", "SUB_MONTHS", "MONTHLY_PAYMENT", 
               "USAGE_FEQ", "STFT", "CHURN"]
    
    return pd.DataFrame(data, columns=columns)

# %%
customer_df = generate_customer_data(200000)
customer_df
# Out:
#         AGE  SUB_MONTHS  MONTHLY_PAYMENT  USAGE_FEQ  STFT  CHURN
# 0        57          86            43.59          4     2   True
# 1        41          25            86.61         16     1   True
# 2        51          13            90.28         26     3  False
# 3        60          91            89.10         11     3  False
# 4        58           9            38.48         19     4  False
# ...     ...         ...              ...        ...   ...    ...
# 199995   51          33            94.09          8     4  False
# 199996   43          61            41.74         22     3   True
# 199997   29         101            28.27         29     4   True
# 199998   37          98            67.49         22     3  False
# 199999   35          48            46.96         29     2  False
#
# [200000 rows x 6 columns]

# %%
customer_df.to_csv('customer_data.csv', index=False)
